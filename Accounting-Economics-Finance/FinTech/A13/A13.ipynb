# %%
import requests

import numpy as np
np.set_printoptions(suppress=True)
import pandas as pd

import altair as alt
import hvplot.pandas
import plotly.express as px

from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler

# %% [markdown]
# ---

# %% [markdown]
# CryptoCompare API [Home](https://min-api.cryptocompare.com)<br>

# %%
url = 'https://min-api.cryptocompare.com/data/all/coinlist'
response = requests.get(url).json()
crypto_df = pd.DataFrame(response['Data']).T
crypto_df = crypto_df[['CoinName', 'Algorithm', 'IsTrading', 'ProofType', 'TotalCoinsMined',]]# 'TotalCoinSupply']]
crypto_df.head()
# Out:
#       CoinName Algorithm IsTrading ProofType TotalCoinsMined
# 42     42 Coin    Scrypt      True   PoW/PoS               0
# 300  300 token       N/A      True       N/A             300
# 365    365Coin       X11      True   PoW/PoS               0
# 404    404Coin    Scrypt      True   PoW/PoS               0
# 433  433 Token       N/A     False       N/A             NaN

# %% [markdown]
# ---

# %%
crypto_df = pd.read_csv('crypto_data.csv', index_col=0)
crypto_df = crypto_df[crypto_df['IsTrading'] == True]     # keep only those cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df['Algorithm'] != 'N/A']    # keep only those cryptocurrencies with a working algorithm
crypto_df = crypto_df.drop(columns=['IsTrading'], axis=1) # drop the IsTrading column
crypto_df = crypto_df.dropna()
crypto_df = crypto_df[crypto_df['TotalCoinsMined'] > 0]   # keep only those cryptocurrencies that have mined coins
coin_name = pd.DataFrame(crypto_df['CoinName'], index=crypto_df.index)
crypto_df = crypto_df.drop('CoinName', axis=1)            # drop the CoinName column
crypto_df['TotalCoinSupply'] = crypto_df['TotalCoinSupply'].astype(float)
crypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01     4.200000e+01
# 404        Scrypt   PoW/PoS     1.055185e+09     5.320000e+08
# 1337          X13   PoW/PoS     2.927942e+10     3.141593e+11
# BTC       SHA-256       PoW     1.792718e+07     2.100000e+07
# ETH        Ethash       PoW     1.076842e+08     0.000000e+00
# ...           ...       ...              ...              ...
# ZEPH      SHA-256      DPoS     2.000000e+09     2.000000e+09
# GAP        Scrypt   PoW/PoS     1.493105e+07     2.500000e+08
# BDX   CryptoNight       PoW     9.802226e+08     1.400223e+09
# ZEN      Equihash       PoW     7.296538e+06     2.100000e+07
# XBC        Scrypt       PoS     1.283270e+05     1.000000e+06
#
# [532 rows x 4 columns]

# %%
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])
X = StandardScaler().fit_transform(X)                     # standardize the data
X
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.145009  , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561,  4.48942416, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.13217937, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.15255998, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.15285552, -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
n_comp = 3
principal_components = PCA(n_components=n_comp).fit_transform(X)
print(principal_components.shape)
pcs_df = pd.DataFrame(principal_components, columns=[f'PC {i}' for i in range(1, n_comp + 1)], index=crypto_df.index)

inertia = []
k = list(range(1, 11))
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)
elbow_data = {'k': k, 'inertia': inertia}
df_elbow = pd.DataFrame(elbow_data)
# Out:
# (532, 98)
# (532, 3)

# %%
df_elbow.hvplot.line(x='k', y='inertia', xticks=k, title='Elbow Curve')
# Out:
# :Curve   [k]   (inertia)

# %%
alt.Chart(df_elbow).mark_line().encode(x='k', y='inertia')
# Out:
# alt.Chart(...)

# %%
model = KMeans(n_clusters=4, random_state=0)
model.fit(pcs_df)
pred = model.predict(pcs_df)

clustered_df = pd.concat([crypto_df, pcs_df], axis=1, sort=False)
clustered_df['CoinName'] = coin_name['CoinName']
clustered_df['Class'] = model.labels_
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1      PC 2  \
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.337823  0.978995
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.321167  0.979106
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  2.313272  1.678143
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.147097 -1.317968
# ETH     Ethash       PoW     1.076842e+08               0 -0.154361 -2.012828
#
#           PC 3   CoinName  Class
# 42   -0.588421    42 Coin      3
# 404  -0.588834    404Coin      3
# 1337 -0.669669  EliteCoin      3
# BTC   0.212701    Bitcoin      0
# ETH   0.419770   Ethereum      0

# %%
fig = px.scatter_3d(
    clustered_df,
    x='PC 1',
    y='PC 2',
    z='PC 3',
    color='Class',
    symbol='Class',
    hover_name='CoinName',
    hover_data=['Algorithm'],
    width=800,
)
fig.update_layout(legend=dict(x=0, y=1))
# Out:
# <div>                            <div id="bdd4619e-0408-46a3-807d-3d5d7bf42a77" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bdd4619e-0408-46a3-807d-3d5d7bf42a77")) {                    Plotly.newPlot(                        "bdd4619e-0408-46a3-807d-3d5d7bf42a77",                        [{"customdata": [["Scrypt"], ["Scrypt"], ["X13"], ["X11"], ["SHA-512"], ["SHA-256"], ["SHA-256"], ["X15"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Groestl"], ["PoS"], ["Scrypt"], ["Scrypt"], ["X11"], ["X11"], ["SHA3"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["X13"], ["X13"], ["NeoScrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X11"], ["X11"], ["Multiple"], ["PHI1612"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X11"], ["Multiple"], ["X13"], ["Scrypt"], ["Shabal256"], ["Counterparty"], ["SHA-256"], ["Groestl"], ["Scrypt"], ["X13"], ["Scrypt"], ["Scrypt"], ["X13"], ["X11"], ["Scrypt"], ["X11"], ["SHA3"], ["QUAIT"], ["X11"], ["Scrypt"], ["X13"], ["SHA-256"], ["X15"], ["BLAKE256"], ["SHA-256"], ["X11"], ["SHA-256"], ["NIST5"], ["Scrypt"], ["Scrypt"], ["X11"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["PoS"], ["X11"], ["SHA-256"], ["SHA-256"], ["NIST5"], ["X11"], ["POS 3.0"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X13"], ["X11"], ["X11"], ["Scrypt"], ["SHA-256"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["SHA-256D"], ["PoS"], ["Scrypt"], ["X11"], ["PoS"], ["X13"], ["X14"], ["PoS"], ["SHA-256D"], ["DPoS"], ["X11"], ["X13"], ["X11"], ["PoS"], ["Scrypt"], ["Scrypt"], ["PoS"], ["X11"], ["SHA-256"], ["Scrypt"], ["X11"], ["Scrypt"], ["Scrypt"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Quark"], ["QuBit"], ["Scrypt"], ["SHA-256"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["X13"], ["Scrypt"], ["Scrypt"], ["X11"], ["Blake2S"], ["X11"], ["PoS"], ["X11"], ["PoS"], ["X11"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["SHA-256"], ["X11"], ["Scrypt"], ["PoS"], ["Scrypt"], ["X15"], ["SHA-256"], ["POS 3.0"], ["536"], ["NIST5"], ["NIST5"], ["Skein"], ["X13"], ["Scrypt"], ["X13"], ["SkunkHash v2 Raptor"], ["Skein"], ["X11"], ["Scrypt"], ["VeChainThor Authority"], ["PoS"], ["Scrypt"], ["Scrypt"], ["SHA-512"], ["Ouroboros"], ["X11"], ["NeoScrypt"], ["Scrypt"], ["Lyra2REv2"], ["Scrypt"], ["SHA-256"], ["NIST5"], ["PHI1612"], ["Scrypt"], ["Quark"], ["POS 2.0"], ["Scrypt"], ["SHA-256"], ["X11"], ["DPoS"], ["NIST5"], ["X13"], ["Scrypt"], ["NIST5"], ["Quark"], ["Scrypt"], ["Scrypt"], ["X11"], ["Quark"], ["Scrypt"], ["Scrypt"], ["X11"], ["POS 3.0"], ["Ethash"], ["Scrypt"], ["Scrypt"], ["X13"], ["C11"], ["X11"], ["XEVAN"], ["Scrypt"], ["VBFT"], ["NIST5"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["Green Protocol"], ["PoS"], ["Scrypt"], ["Semux BFT consensus"], ["Quark"], ["PoS"], ["X16R"], ["Scrypt"], ["XEVAN"], ["Scrypt"], ["Scrypt"], ["Scrypt"], ["SHA-256D"], ["Scrypt"], ["X15"], ["Scrypt"], ["Quark"], ["SHA-256"], ["DPoS"], ["X16R"], ["Quark"], ["Quark"], ["Scrypt"], ["Lyra2REv2"], ["Quark"], ["Scrypt"], ["X11"], ["X11"], ["Scrypt"], ["PoS"], ["Keccak"], ["X11"], ["Scrypt"], ["SHA-512"], ["XEVAN"], ["XEVAN"], ["X11"], ["Quark"], ["Equihash"], ["Scrypt"], ["Quark"], ["Quark"], ["Scrypt"], ["X11"], ["Scrypt"], ["XEVAN"], ["SHA-256D"], ["X11"], ["X11"], ["DPoS"], ["Scrypt"], ["X11"], ["Scrypt"], ["Scrypt"], ["SHA-256"], ["Scrypt"], ["X11"], ["Scrypt"], ["SHA-256"], ["X11"], ["Scrypt"], ["Scrypt"], ["X11"], ["Scrypt"], ["PoS"], ["X11"], ["SHA-256"], ["DPoS"], ["Scrypt"], ["Scrypt"], ["NeoScrypt"], ["X13"], ["DPoS"], ["DPoS"], ["SHA-256"], ["PoS"], ["PoS"], ["SHA-256"], ["Scrypt"], ["Scrypt"]], "hovertemplate": "<b>%{hovertext}</b><br><br>Class=%{marker.color}<br>PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<br>Algorithm=%{customdata[0]}<extra></extra>", "hovertext": ["42 Coin", "404 ...

# %%
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x='PC 1',
    y='PC 2',
    color=alt.Color('Class', scale=alt.Scale(domain=[0, 1, 2, 3], range=['red', 'green', 'blue', 'orange'])),
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply'],
).interactive()
# Out:
# alt.Chart(...)

# %%
clustered_df[['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 'TotalCoinsMined', 'Class']].hvplot.table()
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinSupply,TotalCoinsMined,Class]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(clustered_df[['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 'TotalCoinsMined', 'Class']])
# Out:
#                                 CoinName               Algorithm  \
# 42                               42 Coin                  Scrypt
# 404                              404Coin                  Scrypt
# 1337                           EliteCoin                     X13
# BTC                              Bitcoin                 SHA-256
# ETH                             Ethereum                  Ethash
# LTC                             Litecoin                  Scrypt
# DASH                                Dash                     X11
# XMR                               Monero          CryptoNight-V7
# ETC                     Ethereum Classic                  Ethash
# ZEC                                ZCash                Equihash
# BTS                            Bitshares                 SHA-512
# DGB                             DigiByte                Multiple
# BTCD                         BitcoinDark                 SHA-256
# XPY                              PayCoin                 SHA-256
# PRC                          ProsperCoin                  Scrypt
# KOBO                            KoboCoin                     X15
# SPR                           Spreadcoin                     X11
# ARG                             Argentum                  Scrypt
# AUR                          Aurora Coin                  Scrypt
# BLU                             BlueCoin                  Scrypt
# XMY                           MyriadCoin                Multiple
# MOON                            MoonCoin                  Scrypt
# ZET                             ZetaCoin                 SHA-256
# SXC                              SexCoin                  Scrypt
# QTL                              Quatloo                  Scrypt
# ENRG                          EnergyCoin                  Scrypt
# QRK                            QuarkCoin                   Quark
# RIC                              Riecoin                 Groestl
# DGC                         Digitalcoin                   Scrypt
# BTB                               BitBar                  Scrypt
# CAT                              Catcoin                  Scrypt
# CBX                        CryptoBullion                  Scrypt
# CCN                            CannaCoin                  Scrypt
# CRYPT                          CryptCoin                     X11
# CSC                           CasinoCoin                  Scrypt
# DMD                              Diamond                 Groestl
# XVG                                Verge                Multiple
# DVC                              DevCoin                 SHA-256
# EAC                            EarthCoin                  Scrypt
# EFL                             E-Gulden                  Scrypt
# EMC2                         Einsteinium                  Scrypt
# EMD                              Emerald                  Scrypt
# EXCL                      Exclusive Coin                     PoS
# FLT                          FlutterCoin                  Scrypt
# FRK                               Franko                  Scrypt
# FTC                          FeatherCoin               NeoScrypt
# GDC                            GrandCoin                  Scrypt
# GLC                           GlobalCoin                  Scrypt
# GLD                             GoldCoin                  Scrypt
# HBN                          HoboNickels                  Scrypt
# HYP                           HyperStake                     X11
# IFC                        Infinite Coin                  Scrypt
# IOC                               IOCoin                     X11
# IXC                               IXcoin                 SHA-256
# KGC                           KrugerCoin                  Scrypt
# LKY                            LuckyCoin                  Scrypt
# LTB                             Litebar                   Scrypt
# MAX                              MaxCoin                    SHA3
# MEC                             MegaCoin                  Scrypt
# MED                    MediterraneanCoin     HybridScryptHash256
# MINT                            MintCoin                  Scrypt
# MINC                             MinCoin                  Scrypt
# MZC                             MazaCoin                 SHA-256
# NAUT                       Nautilus Coin                  Scrypt
# NAV                              NavCoin                     X13
# NOBL                           NobleCoin                  Scrypt
# NMC                             Namecoin                 SHA-256
# NYAN                            NyanCoin                  Scrypt
# OPAL                            OpalCoin                     X13
# ORB                            Orbitcoin               NeoScrypt
# POT                              PotCoin                  Scrypt
# PXC                          PhoenixCoin                  Scrypt
# RDD                             Reddcoin                  Scrypt
# RPC                          RonPaulCoin                  Scrypt
# SBC                           StableCoin                  Scrypt
# SMC                            SmartCoin                  Scrypt
# SUPER                          SuperCoin                     X11
# SYNC                            SyncCoin                     X11
# SYS                              SysCoin                 SHA-256
# TES                            TeslaCoin                Multiple
# TGC                            TigerCoin                 SHA-256
# TIT                           TittieCoin                 PHI1612
# TOR                              TorCoin                     X11
# TRC                            TerraCoin                 SHA-256
# UNB                      UnbreakableCoin                 SHA-256
# UNO                           Unobtanium                 SHA-256
# URO                              UroCoin                     X11
# USDE                UnitaryStatus Dollar                  Scrypt
# UTC                            UltraCoin                  Scrypt
# VIA                              ViaCoin                  Scrypt
# VRC                             VeriCoin                  Scrypt
# VTC                             Vertcoin               Lyra2REv2
# WDC                            WorldCoin                  Scrypt
# XC                              X11 Coin                     X11
# XCR                               Crypti                Multiple
# XJO                            JouleCoin                 SHA-256
# XST                          StealthCoin                     X13
# ZCC                             ZCC Coin                  Scrypt
# BCN                             ByteCoin             CryptoNight
# XDN                         DigitalNote              CryptoNight
# BURST                          BurstCoin               Shabal256
# SJCX                           StorjCoin            Counterparty
# MONA                            MonaCoin                  Scrypt
# NTRN                             Neutron                 SHA-256
# FAIR                            FairCoin                 Groestl
# NLG                               Gulden                  Scrypt
# RBY                             RubyCoin                  Scrypt
# PTC                           PesetaCoin                  Scrypt
# KORE                                Kore                     X13
# WBB                      Wild Beast Coin                  Scrypt
# NOTE                              Dnotes                  Scrypt
# FLO                                  Flo                  Scrypt
# 8BIT                           8BIT Coin                  Scrypt
# STV                          Sativa Coin                     X13
# ABY                              ArtByte                  Scrypt
# FLDC                        Folding Coin        Stanford Folding
# U                                  Ucoin                     X11
# UIS                               Unitus                Multiple
# CYP                       CypherPunkCoin                   QuBit
# OMC                             OmniCron                  Scrypt
# VTR                             Vtorrent                  Scrypt
# GRE                            GreenCoin                  Scrypt
# XCN                           Cryptonite                  M7 POW
# MSC                           MasterCoin                  Scrypt
# SOON                            SoonCoin                 SHA-256
# 1CR                              1Credit                  Scrypt
# ISL                             IslaCoin                     X11
# NXS                                Nexus                    SHA3
# MARS                           MarsCoin                      X11
# CTO                               Crypto                 Lyra2RE
# ACP                     Anarchists Prime                 SHA-256
# DRZ                               Droidz                   QUAIT
# BSC                             BowsCoin                     X11
# SQL                          Squall Coin                     X11
# SONG                           Song Coin                  Scrypt
# ZNY                              BitZeny                  Scrypt
# DIGS                             Diggits                  Scrypt
# EXP                              Expanse                  Ethash
# CON                               Paycon                     X13
# SC                               Siacoin                 Blake2b
# EMC                             Emercoin                 SHA-256
# EGC                        EverGreenCoin                     X15
# MND                             MindCoin                     X11
# I0C                               I0coin                 SHA-256
# DCR                               Decred                BLAKE256
# RVR                        Revolution VR                  Scrypt
# HODL                            HOdlcoin  1GB AES Pattern Search
# EDRC                             EDRCoin                 SHA-256
# HTC                              Hitcoin                     X11
# GAME                         Gamecredits                  Scrypt
# DBIC                           DubaiCoin                 SHA-256
# DIEM                       CarpeDiemCoin                 SHA-256
# PWR                             PWR Coin                   NIST5
# BLRY                         BillaryCoin                  Scrypt
# GPU                             GPU Coin                  Scrypt
# ADZ                              Adzcoin                     X11
# SOIL                            SoilCoin                  Dagger
# YOC                               YoCoin                  Scrypt
# SIB                              SibCoin                 X11GOST
# ERC                           EuropeCoin                     X11
# ZEIT                            ZeitCoin                  Scrypt
# SWING                          SwingCoin                 SHA-256
# SAFEX                   SafeExchangeCoin                  Scrypt
# NEBU                      Nebuchadnezzar                     PoS
# FRN                               Francs                  Scrypt
# BOLI                         BolivarCoin                     X11
# XRA                             Ratecoin                     X11
# REV                               Revenu                 SHA-256
# CKC                            Clockcoin                 SHA-256
# VIP                           VIP Tokens                   NIST5
# BSD                              BitSend                     X11
# OMNI                                Omni                  Scrypt
# LIR                          Let it Ride                 POS 3.0
# PUT                            PutinCoin                  Scrypt
# IBANK                          iBankCoin                  Scrypt
# FRWC                      Frankywillcoin                  Scrypt
# MUDRA                          MudraCoin                     X13
# PIZZA                          PizzaCoin                     X11
# LC                         Lutetium Coin                     X11
# KMD                               Komodo                Equihash
# GB                            GoldBlocks                     X11
# CTC                           CarterCoin                  Scrypt
# KRB                                Karbo             CryptoNight
# BXT                            BitTokens                 SHA-256
# ZYD                            ZayedCoin                 SHA-256
# MST                          MustangCoin                     X11
# ZNE                             ZoneCoin                  Scrypt
# COVAL                  Circuits of Value                Multiple
# ROOT                            RootCoin                  Scrypt
# DOPE                            DopeCoin                  Scrypt
# BTCR                         BitCurrency                  Scrypt
# DLC                           DollarCoin                 SHA-256
# SCN                             Swiscoin                  Scrypt
# SH                              Shilling                  Scrypt
# BUZZ                            BuzzCoin                SHA-256D
# XPO                                Opair                     PoS
# PSB                              PesoBit                  Scrypt
# HALLO                     Halloween Coin                     X11
# XZC                                ZCoin                  Lyra2Z
# CFC                           CoffeeCoin                     PoS
# ROYAL                          RoyalCoin                     X13
# GNJ                         GanjaCoin V2                     X14
# TEAM                              TeamUP                     PoS
# LANA                            LanaCoin                SHA-256D
# ELE                           Elementrem                  Ethash
# ZCL                             ZClassic                Equihash
# ARK                                  ARK                    DPoS
# INSANE                        InsaneCoin                     X11
# KLC                             KiloCoin                  Scrypt
# ATX                            ArtexCoin                     X11
# EMB                            EmberCoin                     X13
# XEN                            XenixCoin                     X11
# FRE                             FreeCoin                     PoS
# PLNC                             PLNCoin                  Scrypt
# ARCO                        AquariusCoin                  Scrypt
# KURT                             Kurrent                     X11
# XCRE                             Creatio                     PoS
# ENT                             Eternity                     X11
# EUC                             Eurocoin                 SHA-256
# BCF                          BitcoinFast                  Scrypt
# XSN                             Stakenet                     X11
# BCCOIN                   BitConnect Coin                  Scrypt
# MONEY                          MoneyCoin                  Scrypt
# XNG                               Enigma                     X11
# XCI               Cannabis Industry Coin             CryptoNight
# RC                            Russiacoin                  Scrypt
# PND                            PandaCoin                  Scrypt
# UNITS                          GameUnits                  Scrypt
# GAKH                            GAKHcoin                  Scrypt
# ASAFE2                           Allsafe                   Quark
# LTCR                           LiteCreed                   QuBit
# OS76                          OsmiumCoin                  Scrypt
# BIC                           Bikercoins             CryptoNight
# HXX                             HexxCoin                 Lyra2RE
# KED                Klingon Empire Darsek                  Scrypt
# IOP                   Internet of People                 SHA-256
# KUSH                            KushCoin                     X11
# PRX                           Printerium                  Scrypt
# PAC                              PacCoin                     X11
# IMPCH                            Impeach                  Scrypt
# CTL                              Citadel          CryptoNight-V7
# ZBC                           Zilbercoin                  Scrypt
# FRST                           FirstCoin                  Scrypt
# BVC                           BeaverCoin                  Scrypt
# FIND                            FindCoin                     X13
# VLTC                           VaultCoin                     X11
# ZER                                 Zero                Equihash
# CHAT                            OpenChat                  Scrypt
# CDN                         Canada eCoin                  Scrypt
# ZOI                                 Zoin                 Lyra2RE
# RNS                            RenosCoin                  Scrypt
# DBIX                           DubaiCoin        Dagger-Hashimoto
# XVP                        VirtacoinPlus                     X11
# TAJ                              TajCoin                 Blake2S
# IMX                               Impact                     X11
# EB3                              EB3coin                  Scrypt
# ATMOS                              Atmos                     PoS
# HPC                            HappyCoin                     X11
# CXT                             Coinonat                   NIST5
# MCRN                          MacronCoin                     PoS
# RAIN                          Condensate                     X11
# IMS             Independent Money System                  Scrypt
# ARGUS                          ArgusCoin                  Scrypt
# LMC                             LomoCoin                  Scrypt
# PROC                         ProCurrency                 SHA-256
# XGR                          GoldReserve                     X11
# BENJI                         BenjiRolls                  Scrypt
# GRW                           GrowthCoin                  Scrypt
# ILC                               ILCoin                 SHA-256
# PHR                               Phreak                     PoS
# DEA                           Degas Coin                  Scrypt
# HTML5                         HTML5 Coin                     X15
# USC                 Ultimate Secure Cash                 SHA-256
# EQT                           EquiTrader                  Scrypt
# QTUM                                QTUM                 POS 3.0
# QRL             Quantum Resistant Ledger          CryptoNight-V7
# ESP                               Espers                     536
# DYN                              Dynamic                 Argon2d
# NANO                                Nano                 Blake2b
# CHAN                            ChanCoin              Cloverhash
# DCY                          Dinastycoin             CryptoNight
# DNR                             Denarius                   NIST5
# DP                          DigitalPrice                     X11
# VUC                    Virta Unique Coin                   NIST5
# BTPL                      Bitcoin Planet                   Skein
# UNIFY                              Unify                  Scrypt
# BRIT                            BritCoin                     X13
# SOCC                          SocialCoin                  Scrypt
# ARC                           ArcticCoin                     X11
# DAS                                  DAS                     X11
# LINDA                              Linda                  Scrypt
# XLC                           LeviarCoin             CryptoNight
# ONION                          DeepOnion                     X13
# BTX                              Bitcore             Time Travel
# GCN                             gCn Coin                  Scrypt
# SMART                          SmartCash                  Keccak
# SIGT                            Signatum     SkunkHash v2 Raptor
# ONX                                 Onix                     X11
# CRM                                Cream                   Skein
# BCH                         Bitcoin Cash                 SHA-256
# XMCC                             Monoeci                     X11
# DFT                            Draftcoin                  Scrypt
# VET                              Vechain   VeChainThor Authority
# SOJ                         Sojourn Coin                  Scrypt
# STCN                           Stakecoin                     PoS
# NYC                          NewYorkCoin                  Scrypt
# FRAZ                            FrazCoin                  Scrypt
# KRONE                          Kronecoin                  Scrypt
# ACC                               AdCoin                  Scrypt
# LINX                                Linx                  Scrypt
# XCXT                           CoinonatX                  Scrypt
# ETHD                       Ethereum Dark                  Scrypt
# SUMO                            Sumokoin             CryptoNight
# ODN                             Obsidian                 SHA-512
# ADA                              Cardano               Ouroboros
# REC                            Regalcoin                     X11
# BTCZ                            BitcoinZ                Equihash
# TZC                           TrezarCoin               NeoScrypt
# ELM                             Elements                     X11
# TER                        TerraNovaCoin                  Scrypt
# VIVO                           VIVO Coin               NeoScrypt
# RUP                                Rupee               Lyra2REv2
# BTG                         Bitcoin Gold                Equihash
# WOMEN                          WomenCoin                  Scrypt
# MAY                     Theresa May Coin                 SHA-256
# NAMO                            NamoCoin                   NIST5
# LUX                              LUXCoin                 PHI1612
# PIRL                                Pirl                  Dagger
# XIOS                                Xios                  Scrypt
# BTDX                        Bitcloud 2.0                   Quark
# EBST                              eBoost                  Scrypt
# KEK                              KekCoin                 POS 2.0
# BLHC                       BlackholeCoin                  Scrypt
# XIN                   Infinity Economics                 SHA-256
# PURA                                Pura                     X11
# INN                               Innova               NeoScrypt
# ELLA                             Ellaism                  Ethash
# GBX                               GoByte               NeoScrypt
# MAG                               Magnet                     X11
# TAU                           Lamden Tau                    DPoS
# ECA                              Electra                   NIST5
# BCD                      Bitcoin Diamond                     X13
# XSH                               SHIELD                Multiple
# CNBC                    Cash & Back Coin                  Scrypt
# XUN                            UltraNote             CryptoNight
# COAL                             BitCoal             CryptoNight
# DAXX                            DaxxCoin                  Ethash
# BWK                              Bulwark                   NIST5
# KLKS                            Kalkulus                   Quark
# AC3                                  AC3                     X11
# LTHN                             Lethean          CryptoNight-V7
# GER                           GermanCoin                  Scrypt
# LTCU                      LiteCoin Ultra                  Scrypt
# POP                          PopularCoin                  Scrypt
# PNX                             PhantomX                     X11
# PHO                               Photon                BLAKE256
# SUCR                               Sucre                     X11
# SPK                            SparksPay               NeoScrypt
# WAGE                            Digiwage                   Quark
# GUN                              GunCoin               NeoScrypt
# IRL                            IrishCoin                  Scrypt
# TROLL                          Trollcoin                  Scrypt
# LCP                        Litecoin Plus                  Scrypt
# MONK                      Monkey Project                     X11
# PCOIN                       Pioneer Coin                     X11
# UBTC                       UnitedBitcoin                 SHA-256
# ITZ                            Interzone                     C11
# TPAY                            TokenPay                 POS 3.0
# MCT     1717 Masonic Commemorative Token                  Ethash
# MBC                          My Big Coin                  Scrypt
# TRTL                          TurtleCoin             CryptoNight
# MUN                              MUNcoin               SkunkHash
# USX                Unified Society USDEX                  Scrypt
# NBR                          Niobio Cash             CryptoNight
# SSS                           ShareChain                  Scrypt
# TRF                           Travelflex                  Dagger
# KREDS                              KREDS               Lyra2REv2
# TOKC                          Tokyo Coin                     X13
# BBP                             BiblePay      Proof-of-BibleHash
# LCC                         LitecoinCash          SHA-256 + Hive
# FLIP                             BitFlip                  Scrypt
# LOT                            LottoCoin                  Scrypt
# CIF              Crypto Improvement Fund                     X11
# SPD                              Stipend                     C11
# POA                          Poa Network      Proof-of-Authority
# PUSHI                              Pushi                     X11
# ELP                             Ellerium                   XEVAN
# VLX                                Velox                  Scrypt
# ONT                             Ontology                    VBFT
# CLO                     Callisto Network                  Ethash
# TUBE                             BitTube             CryptoNight
# PSD                             Poseidon                  Scrypt
# ADK                         Aidos Kuneen                   IMesh
# BSX                             Bitspace                   NIST5
# BRIA                            Briacoin                  Scrypt
# IC                              Ignition                  Scrypt
# BTL                            Bitrolium                Equihash
# MEDIC                          MedicCoin                  Scrypt
# ALPS                     Alpenschillling                  Lyra2Z
# BITG                       Bitcoin Green          Green Protocol
# DEV                         Deviant Coin                     PoS
# ABJ                              Abjcoin                  Scrypt
# SEM                                Semux     Semux BFT consensus
# FTO                           FuturoCoin                     X11
# CARE                             Carebit                   Quark
# NZL                              Zealium                     PoS
# XMC                       Monero Classic             CryptoNight
# PROTON                            Proton                    X16R
# DEAL                           iDealCash                  Scrypt
# JUMP                            Jumpcoin                   NIST5
# INFX                             Infinex                 Lyra2RE
# XBI                    Bitcoin Incognito                   XEVAN
# KEC                                KEYCO                  Tribus
# HWC                        HollyWoodCoin                  Scrypt
# GIN                              GINcoin                  Lyra2Z
# PLTC                          PlatinCoin             CryptoNight
# LOKI                                Loki       CryptoNight Heavy
# NCP                          Newton Coin             CryptoNight
# SIC                            Swisscoin                  Scrypt
# XT3                                Xt3ch                  Scrypt
# MGD                             MassGrid    Jump Consistent Hash
# VIG                               TheVig                SHA-256D
# PLURA                          PluraCoin             CryptoNight
# EMAR                          EmaratCoin                  Scrypt
# DKD                               Dekado                     X15
# LYNX                                Lynx                  Scrypt
# POSQ                      Poseidon Quark                   Quark
# BWS                     BitcoinWSpectrum                 SHA-256
# MUSE                                Muse                    DPoS
# XMN                               Motion                    X16R
# PLUS1                        PlusOneCoin                 HMQ1725
# AXE                                  Axe                     X11
# TRVC                          Trivechain                    X16R
# DTEM                              Dystem                   Quark
# GIC                                Giant                   Quark
# PNY                           Peony Coin                  Scrypt
# ABS                        Absolute Coin               Lyra2REv2
# VITAE                              Vitae                   Quark
# HEX                              HexCoin                  Scrypt
# TPC                               TPCash                  Scrypt
# WEBC                            Webchain          CryptoNight-V7
# RYO                                  Ryo         Cryptonight-GPU
# URALS                         Urals Coin                   XEVAN
# QWC                           Qwertycoin       CryptoNight Heavy
# ARE                               ARENON                     X11
# EUNO                                EUNO                     X11
# MMO                              MMOCoin                  Scrypt
# KETAN                              Ketan                     PoS
# PPAI                         Project Pai                 SHA-256
# XDNA                                XDNA                  Keccak
# PAXEX                              PAXEX                     X11
# AZART                              Azart                     X11
# TSC                         ThunderStake                  Scrypt
# KCASH                              Kcash                 SHA-512
# XCG                              Xchange                    X16R
# AAC                    Acute Angle Cloud               ECC 256K1
# CRYP                         CrypticCoin                Equihash
# BTXC                         Bettex coin                   XEVAN
# ACM                             Actinium                  Lyra2Z
# BSV                           Bitcoin SV                 SHA-256
# BITM                            BitMoney                   XEVAN
# JMC                Junson Ming Chan Coin                     X11
# FRED                          FREDEnergy             CryptoNight
# HERB                            HerbCoin                   Quark
# UMO                   Universal Molecule                   Blake
# LIT                              Lithium                   Blake
# PIRATE                        PirateCash                Equihash
# EXO                               Exosis                  Exosis
# BLTG                         Block-Logic                  Scrypt
# OWC                                Oduwa                  Scrypt
# BEAM                                Beam                Equihash
# GALI                             Galilel                   Quark
# BTH                            Bithereum                Equihash
# CSPN                       Crypto Sports                   Quark
# CREDIT                            Credit                  Scrypt
# SLC                                SLICE                   QuBit
# DASHP                      Dash Platinum                     X11
# NSD                            Nasdacoin                  Scrypt
# BEET                         Beetle Coin                   XEVAN
# TTN                           Titan Coin                SHA-256D
# AWR                                Award                     X11
# BLAST                              BLAST                 SHA-256
# XRC                      Bitcoin Rhodium                     X13
# GLT                          GlobalToken                 SHA-256
# INSN                         Insane Coin                     X11
# ALX                                 ALAX                    DPoS
# LDOGE                           LiteDoge                  Scrypt
# SLR                            SolarCoin                  Scrypt
# TRK                            TruckCoin                     X11
# UFO                             UFO Coin               NeoScrypt
# OC                            OrangeCoin                  Scrypt
# BLC                            BlakeCoin                   Blake
# BITS                         BitstarCoin                  Scrypt
# NEOS                            NeosCoin                 SHA-256
# HYPER                          HyperCoin                  Scrypt
# PINK                            PinkCoin                     X11
# CESC                       Crypto Escudo                  Scrypt
# ADC                            AudioCoin                  Scrypt
# NKA                             IncaKoin                 SHA-256
# PIGGY                         Piggy Coin                     X11
# CRW                           Crown Coin                 SHA-256
# GEN                             Genstake                  Scrypt
# SMLY                          SmileyCoin                  Scrypt
# MI                            XiaoMiCoin                  Scrypt
# GRS                          Groestlcoin                 Groestl
# CPC                            CapriCoin                     X11
# CLUB                            ClubCoin                  Scrypt
# RADS                              Radium                     PoS
# BTA                                 Bata                  Scrypt
# PAK                              Pakcoin                  Scrypt
# CRB                           Creditbit                      X11
# OK                                OKCash                 SHA-256
# LSK                                 Lisk                    DPoS
# XHI                               HiCoin                  Scrypt
# XWC                            WhiteCoin                  Scrypt
# FSC                       FriendshipCoin               NeoScrypt
# J                               JoinCoin                Multiple
# TRI                       Triangles Coin                     X13
# VOLLAR                            Vollar         Equihash+Scrypt
# EOS                                  EOS                    DPoS
# RCC                        Reality Clash                  Ethash
# OXY                              Oxycoin                    DPoS
# TCH                            TigerCash                 SHA-256
# WAVES                              Waves              Leased POS
# PART                             Particl                     PoS
# BTT                           BitTorrent                   TRC10
# NXT                                  Nxt                     PoS
# ZEPH                              ZEPHYR                 SHA-256
# GAP                              Gapcoin                  Scrypt
# BDX                               Beldex             CryptoNight
# ZEN                              Horizen                Equihash
# XBC                          BitcoinPlus                  Scrypt
#
#                    ProofType    TotalCoinSupply  TotalCoinsMined  Class
# 42                   PoW/PoS                 42     4.199995e+01      3
# 404                  PoW/PoS          532000000     1.055185e+09      3
# 1337                 PoW/PoS       314159265359     2.927942e+10      3
# BTC                      PoW           21000000     1.792718e+07      0
# ETH                      PoW                  0     1.076842e+08      0
# LTC                      PoW           84000000     6.303924e+07      0
# DASH                 PoW/PoS           22000000     9.031294e+06      3
# XMR                      PoW                  0     1.720114e+07      0
# ETC                      PoW          210000000     1.133597e+08      0
# ZEC                      PoW           21000000     7.383056e+06      0
# BTS                      PoS         3600570502     2.741570e+09      3
# DGB                      PoW        21000000000     1.140622e+10      0
# BTCD                 PoW/PoS           22000000     1.288862e+06      3
# XPY                      PoS           12500000     1.199533e+07      3
# PRC                      PoW           21000000     5.768310e+06      0
# KOBO                 PoW/PoS          350000000     2.554254e+07      3
# SPR                      PoW           20000000     1.114973e+07      0
# ARG                      PoW           64000000     1.220580e+07      0
# AUR                  PoW/PoS           16768584     1.813510e+07      3
# BLU                  PoW/PoS                  0     6.354239e+08      3
# XMY                      PoW         2000000000     1.688254e+09      0
# MOON                     PoW       384000000000     8.800000e+01      0
# ZET                      PoW          169795588     1.702044e+08      0
# SXC                      PoW          250000000     1.289410e+08      0
# QTL                      PoW          100000000     7.357795e+06      0
# ENRG                 PoW/PoS                  0     1.230628e+08      3
# QRK                      PoW          247000000     2.595572e+08      0
# RIC                      PoW           84000000     4.954859e+07      0
# DGC                      PoW           48166000     3.344299e+07      0
# BTB                  PoW/PoS             500000     4.257948e+04      3
# CAT                      PoW          21000000      7.219957e+06      0
# CBX                  PoW/PoS            1000000     1.039117e+06      3
# TRK                  PoW/PoS                  0     2.425741e+08      3
# UFO                      PoW         4000000000     3.824685e+09      0
# OC                   PoW/PoS          200000000     3.537150e+06      3
# BLC                      PoW         7000000000     2.335679e+07      0
# BITS                 PoW/PoS           54256119     2.057653e+07      3
# NEOS                     PoS           21000000     4.392258e+06      3
# HYPER                PoW/PoS                  0     9.631200e+06      3
# PINK                 PoW/PoS          500000000     4.363536e+08      3
# CESC                     PoW         1000000000     7.802107e+08      0
# ADC                  PoW/PoS        10500000000     9.807325e+08      3
# NKA                  PoW/PoS          190000000     1.793973e+10      3
# PIGGY                PoW/PoS         1000000000     4.942407e+08      3
# CRW                      PoW           42000000     2.298693e+07      0
# GEN                  PoW/PoS           15000000     6.000000e+07      3
# SMLY                     PoW        50000000000     2.958399e+10      0
# MI                   PoW/PoS          400000000     4.043165e+08      3
# GRS                      PoW          105000000     7.329820e+07      0
# CPC                  PoW/PoS          208000000     2.013643e+08      3
# CLUB                 PoW/PoS          160000000     1.036219e+08      3
# RADS                     PoS            9000000     3.821246e+06      3
# BTA                      PoW            5000000     5.052556e+06      0
# PAK                      PoW          182000000     6.968446e+07      0
# CRB           Proof of Trust           16504333     1.690102e+07      3
# OK                   PoW/PoS          105000000     7.467606e+07      3
# LSK                     DPoS          159918400     1.200121e+08      3
# XHI                      PoS        10008835635     1.000024e+10      3
# XWC                  PoW/PoS          300000000     2.520056e+08      3
# FSC                  PoW/PoS           60168145     1.120385e+06      3
# J                        PoW            2800000     3.332922e+06      0
# TRI                  PoW/PoS             120000     1.407778e+05      3
# VOLLAR                   PoW         2100000000     1.000000e+08      0
# EOS                     DPoS                  0     1.020545e+09      3
# RCC                      PoW           24487944     2.448794e+07      0
# OXY                     DPoS                  0     1.122382e+09      3
# TCH                      PoS         1000000000     1.000000e+09      3
# WAVES                   LPoS          100000000     1.000000e+08      1
# PART                     PoS            8634140     9.283138e+06      3
# BTT                     DPoS       990000000000     9.899887e+11      2
# NXT                 PoS/LPoS         1000000000     1.000000e+09      3
# ZEPH                    DPoS         2000000000     2.000000e+09      3
# GAP                  PoW/PoS          250000000     1.493105e+07      3
# BDX                      PoW         1400222610     9.802226e+08      0
# ZEN                      PoW           21000000     7.296538e+06      0
# XBC                      PoS            1000000     1.283270e+05      3

# %%
plot_data = MinMaxScaler().fit_transform(clustered_df[['TotalCoinSupply', 'TotalCoinsMined']])
plot_df = pd.DataFrame(plot_data, columns=['TotalCoinSupply', 'TotalCoinsMined'], index=clustered_df.index)
plot_df['CoinName'] = clustered_df['CoinName']
plot_df['Class'] = clustered_df['Class']
plot_df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply', hover_cols=['Coinname'], by='Class')
# Out:
# :NdOverlay   [Class]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply)

# %%
alt.Chart(plot_df).mark_circle(size=60).encode(
    x='TotalCoinsMined',
    y='TotalCoinSupply',
    color=alt.Color('Class', scale=alt.Scale(domain=[0, 1, 2, 3], range=['red', 'green', 'blue', 'orange'])),
    tooltip=['CoinName', 'TotalCoinsMined', 'TotalCoinSupply'],
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ---
