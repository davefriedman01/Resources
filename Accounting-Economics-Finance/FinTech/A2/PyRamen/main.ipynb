# %% [markdown]
# # Python

# %%
# imports
import csv

# %%
# read the menu data
#   item, category, description, price, cost
menu_data, header = [], ''
with open('menu_data.csv') as menu_data_file:
    reader = csv.reader(menu_data_file)
    print(next(reader)) # skip the header
    for row in reader:
        menu_data.append(row)
# Out:
# ['item', 'category', 'description', 'price', 'cost']

# %%
# view the menu data
print(len(menu_data))
for menu_datum in menu_data[:2]:
    print(menu_datum)
# Out:
# 32
# ['edamame', 'appetizers', 'boiled soybeans, maldon sea salt', '4', '1']
# ['house salad', 'appetizers', 'mixed greens, cherry tomatoes, cucumber, house ginger dressing', '4', '2']

# %%
# read the sales data
#   Line_Item_ID, Date, Credit_Card_Number, Description, Quantity, Menu_Item
sales_data = []
with open('sales_data.csv') as sales_data_file:
    reader = csv.reader(sales_data_file)
    print(next(reader)) # skip the header
    for row in reader:
        sales_data.append(row)
# Out:
# ['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item']

# %%
# view the sales data
print(len(sales_data))
for sales_datum in sales_data[:2]:
    print(sales_datum)
# Out:
# 74124
# ['1', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen']
# ['2', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen']

# %%
# process the data
report, count = {}, 0
for sales_record in sales_data:
    sales_item = sales_record[4]
    sales_item_quantity = int(sales_record[3])
    if sales_item not in report.keys():
        report[sales_item] = {
            '01-count': 0,
            '02-revenue': 0,
            '03-cost': 0,
            '04-profit': 0,
        }
    for menu_record in menu_data:
        menu_item = menu_record[0]
        menu_item_price = float(menu_record[3])
        menu_item_cost = float(menu_record[4])
        menu_item_profit = menu_item_price - menu_item_cost
        if sales_item == menu_item:
            report[sales_item]['01-count'] += sales_item_quantity
            report[sales_item]['02-revenue'] += menu_item_price * sales_item_quantity
            report[sales_item]['03-cost'] += menu_item_cost * sales_item_quantity
            report[sales_item]['04-profit'] += menu_item_profit * sales_item_quantity
    count += 1

# %%
# write the report
with open('python_report.txt', 'w') as python_report_file:
    for key, value in sorted(report.items()):
        python_report_file.write(f'{key} {value}\n')

# %%
# print the report
print(count)
for item_report in sorted(report.items()):
    print(item_report)
# Out:
# 74124
# ('burnt garlic tonkotsu ramen', {'01-count': 9070, '02-revenue': 126980.0, '03-cost': 54420.0, '04-profit': 72560.0})
# ('miso crab ramen', {'01-count': 8890, '02-revenue': 106680.0, '03-cost': 53340.0, '04-profit': 53340.0})
# ('nagomi shoyu', {'01-count': 9132, '02-revenue': 100452.0, '03-cost': 45660.0, '04-profit': 54792.0})
# ('shio ramen', {'01-count': 9180, '02-revenue': 100980.0, '03-cost': 45900.0, '04-profit': 55080.0})
# ('soft-shell miso crab ramen', {'01-count': 9130, '02-revenue': 127820.0, '03-cost': 63910.0, '04-profit': 63910.0})
# ('spicy miso ramen', {'01-count': 9238, '02-revenue': 110856.0, '03-cost': 46190.0, '04-profit': 64666.0})
# ('tonkotsu ramen', {'01-count': 9288, '02-revenue': 120744.0, '03-cost': 55728.0, '04-profit': 65016.0})
# ('tori paitan ramen', {'01-count': 9156, '02-revenue': 119028.0, '03-cost': 54936.0, '04-profit': 64092.0})
# ('truffle butter ramen', {'01-count': 8982, '02-revenue': 125748.0, '03-cost': 62874.0, '04-profit': 62874.0})
# ('vegetarian curry + king trumpet mushroom ramen', {'01-count': 8824, '02-revenue': 114712.0, '03-cost': 61768.0, '04-profit': 52944.0})
# ('vegetarian spicy miso', {'01-count': 9216, '02-revenue': 110592.0, '03-cost': 46080.0, '04-profit': 64512.0})

# %% [markdown]
# ---

# %% [markdown]
# # Pandas

# %%
# imports
import pandas as pd

# %%
# read the menu data
menu_df = pd.read_csv('menu_data.csv', index_col='item').drop(columns=['category', 'description']).astype(float)
menu_df['profit'] = menu_df.price - menu_df.cost

# %%
# view the menu data
print(menu_df.shape)
menu_df
# Out:
# (32, 3)
#                                                 price  cost  profit
# item
# edamame                                           4.0   1.0     3.0
# house salad                                       4.0   2.0     2.0
# cucumber sunomono salad                           5.0   2.0     3.0
# hiyashi wakame seaweed salad                      5.0   2.0     3.0
# agedashi tofu                                     5.0   2.0     3.0
# hiyayakko tofu                                    5.0   2.0     3.0
# pork floss bao                                    4.0   2.0     2.0
# kakuni bao                                        6.0   3.0     3.0
# edamame fried gyoza (vegan)                       6.0   3.0     3.0
# fried gyoza                                       6.0   6.0     0.0
# takoyaki                                          6.0   3.0     3.0
# rock shrimp tempura                               6.0   3.0     3.0
# soft-shell crab tempura                           6.0   3.0     3.0
# ebi katsu shrimp bao                              6.0   3.0     3.0
# nagomi shoyu                                     11.0   5.0     6.0
# shio ramen                                       11.0   5.0     6.0
# spicy miso ramen                                 12.0   5.0     7.0
# vegetarian spicy miso                            12.0   5.0     7.0
# miso crab ramen                                  12.0   6.0     6.0
# soft-shell miso crab ramen                       14.0   7.0     7.0
# tori paitan ramen                                13.0   6.0     7.0
# tonkotsu ramen                                   13.0   6.0     7.0
# burnt garlic tonkotsu ramen                      14.0   6.0     8.0
# vegetarian curry + king trumpet mushroom ramen   13.0   7.0     6.0
# truffle butter ramen                             14.0   7.0     7.0
# green tea                                         2.5   1.0     1.5
# coke                                              2.0   1.0     1.0
# black sesame ice cream                            5.0   2.0     3.0
# matcha ice cream                                  5.0   2.0     3.0
# mango mochi ice cream                             5.0   2.0     3.0
# strawberry mochi ice cream                        5.0   2.0     3.0
# black sesame creme brulee                         6.0   3.0     3.0

# %%
# read the sales data
sales_df = pd.read_csv('sales_data.csv', index_col='Line_Item_ID').drop(columns=['Date', 'Credit_Card_Number'])

# %%
# view the sales data
print(sales_df.shape)
sales_df.head()
# Out:
# (74124, 2)
#               Quantity             Menu_Item
# Line_Item_ID
# 1                    1      spicy miso ramen
# 2                    1      spicy miso ramen
# 3                    3     tori paitan ramen
# 4                    3     tori paitan ramen
# 5                    1  truffle butter ramen

# %%
quantity = sales_df.groupby('Menu_Item').sum().iloc[:, 0]
quantity
# Out:
# Menu_Item
# burnt garlic tonkotsu ramen                       9070
# miso crab ramen                                   8890
# nagomi shoyu                                      9132
# shio ramen                                        9180
# soft-shell miso crab ramen                        9130
# spicy miso ramen                                  9238
# tonkotsu ramen                                    9288
# tori paitan ramen                                 9156
# truffle butter ramen                              8982
# vegetarian curry + king trumpet mushroom ramen    8824
# vegetarian spicy miso                             9216
# Name: Quantity, dtype: int64

# %%
relevant_menu_df = menu_df[menu_df.index.isin(sales_df.Menu_Item.unique())].sort_index()
relevant_menu_df
# Out:
#                                                 price  cost  profit
# item
# burnt garlic tonkotsu ramen                      14.0   6.0     8.0
# miso crab ramen                                  12.0   6.0     6.0
# nagomi shoyu                                     11.0   5.0     6.0
# shio ramen                                       11.0   5.0     6.0
# soft-shell miso crab ramen                       14.0   7.0     7.0
# spicy miso ramen                                 12.0   5.0     7.0
# tonkotsu ramen                                   13.0   6.0     7.0
# tori paitan ramen                                13.0   6.0     7.0
# truffle butter ramen                             14.0   7.0     7.0
# vegetarian curry + king trumpet mushroom ramen   13.0   7.0     6.0
# vegetarian spicy miso                            12.0   5.0     7.0

# %%
product_df = pd.DataFrame({
    'quantity': quantity,
    'revenue':  quantity * relevant_menu_df.price,
    'cost':     quantity * relevant_menu_df.cost,
    'profit':   quantity * relevant_menu_df.profit,
},
    index=sales_df.Menu_Item.sort_values().unique()
    # index=sales_df.Menu_Item.sort_values().drop_duplicates().values
)
#product_df = pd.DataFrame(
#    index=sales_df.Menu_Item.sort_values().unique()
#    # index=sales_df.Menu_Item.sort_values().drop_duplicates().values
#)
#product_df['quantity'] = quantity
#product_df['revenue'] =  quantity * relevant_menu_df.price
#product_df['cost'] =     quantity * relevant_menu_df.cost
#product_df['profit'] =   quantity * relevant_menu_df.profit

# %%
# write the report
with open('pandas_report.txt', 'w') as pandas_report_file:
    pandas_report_file.write(product_df.to_string())

# %%
# print the report
product_df.style.format({'revenue': '${:,.2f}', 'cost': '${:,.2f}', 'profit': '${:,.2f}'})\
.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col0 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col1 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col2 {
#             background-color:  #74b3d8;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col0 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col1 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col2 {
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col3 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row2_col0 {
#             background-color:  #3888c1;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row2_col3 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row3_col0 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row3_col1 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row3_col2 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row3_col3 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row4_col0 {
#             background-color:  #3989c1;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row4_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row4_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row4_col3 {
#             background-color:  #57a0ce;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row5_col0 {
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row5_col1 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row5_col2 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row5_col3 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row6_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row6_col1 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row6_col2 {
#             background-color:  #5aa2cf;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row6_col3 {
#             background-color:  #4594c7;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row7_col0 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row7_col1 {
#             background-color:  #3484bf;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row7_col2 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row7_col3 {
#             background-color:  #549fcd;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row8_col0 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row8_col1 {
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row8_col2 {
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row8_col3 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row9_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row9_col1 {
#             background-color:  #64a9d3;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row9_col2 {
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row9_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row10_col0 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row10_col1 {
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row10_col2 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row10_col3 {
#             background-color:  #4e9acb;
#             color:  #000000;
#         }</style><table id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >quantity</th>        <th class="col_heading level0 col1" >revenue</th>        <th class="col_heading level0 col2" >cost</th>        <th class="col_heading level0 col3" >profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7level0_row0" class="row_heading level0 row0" >burnt garlic tonkotsu ramen</th>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col0" class="data row0 col0" >9070</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col1" class="data row0 col1" >$126,980.00</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col2" class="data row0 col2" >$54,420.00</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row0_col3" class="data row0 col3" >$72,560.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7level0_row1" class="row_heading level0 row1" >miso crab ramen</th>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col0" class="data row1 col0" >8890</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col1" class="data row1 col1" >$106,680.00</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col2" class="data row1 col2" >$53,340.00</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row1_col3" class="data row1 col3" >$53,340.00</td>
#             </tr>
#             <tr>
#                         <th id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7level0_row2" class="row_heading level0 row2" >nagomi shoyu</th>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row2_col0" class="data row2 col0" >9132</td>
#                         <td id="T_4e75ff5c_86d5_11eb_b065_f45c89b775f7row2_col1" class="data row2 col1" >$100,452.00</td>
#                         <td id="T_4e75ff5c_86d5_

# %% [markdown]
# ---
